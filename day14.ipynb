# %% [markdown]
# <a href="https://colab.research.google.com/github/datajcthemax/playdata/blob/main/day14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 14번째 스토리
# - 데이터 시각화의 개념
# - 데이터 시각화의 라이브러리 학습
# - 데이터 시각화 실습

# %%
import folium

m = folium.Map(location=[37.5665, 126.9780], zoom_start=12)
folium.Marker([37.5665, 126.9780], popup='서울시청').add_to(m)
m.save('map.html')

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Line Plot

# %%
import matplotlib.pyplot as plt
# plt.figure() # 도화지 
fig = plt.figure(figsize=(10,3)) # 도화지

# %%
ax = plt.axes()

# %%
fig = plt.figure(figsize=(20,20)) # 도화지 
ax=plt.axes()

# %%
plt.plot([0,0.2, 0.3, 0.5, 1.0], 'g*-.')

# %%
import numpy as np
x = np.arange(0, 10, 0.01)
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));
# .py => plt.show()

# %%
plt.plot(np.random.randn(50).cumsum());

# %% [markdown]
# ## line style
# - '-' solid
# - '--' dashed
# - '-.' dashdot
# - ':' dotted

# %%
plt.plot(np.random.randn(50).cumsum(), '-');
plt.plot(np.random.randn(50).cumsum(), linestyle='--');
plt.plot(np.random.randn(50).cumsum(), '-.')
plt.plot(np.random.randn(50).cumsum(), ':');

# %% [markdown]
# # 색상
# - b, g, r, c(cyan), m(margenta), y, k(black), w

# %%
plt.plot(np.random.randn(50).cumsum(), 'c')
plt.plot(np.random.randn(50).cumsum(), 'm')
plt.plot(np.random.randn(50).cumsum(), 'y')
plt.plot(np.random.randn(50).cumsum(), 'g')

# %% [markdown]
# # Axis

# %%
plt.plot(np.random.randn(50))

# %%
np.random.randn(50)
# Out:
# array([-0.07815838,  1.20268707, -0.79218416, -0.44572196,  0.92975732,
#        -0.0963605 ,  0.71742009, -0.44673793, -0.95506978,  1.11442049,
#        -1.56760192,  1.44984744,  1.36921675, -0.56744173, -0.54057337,
#         0.75309551, -1.34017752, -0.0533033 , -1.14648783,  1.16751242,
#        -0.07787877, -0.46965174, -2.13948792, -1.4929754 ,  0.42574584,
#        -3.17685731,  0.89943177, -1.2382262 ,  0.23472197, -0.1443825 ,
#        -0.4317713 , -0.6353267 ,  0.58845142,  0.13012658,  0.23183807,
#         0.48897737,  1.51169812,  0.99384017,  0.74275047,  0.94646596,
#         0.29225355,  0.84102792, -0.0938315 , -0.11422387, -0.00723234,
#        -0.70861969, -1.71663693,  0.03190442,  0.49038078,  2.17871674])

# %%
np.random.rand(50)
# Out:
# array([0.55854437, 0.60319588, 0.98903842, 0.32186295, 0.94516886,
#        0.49863711, 0.85273454, 0.75521732, 0.1815636 , 0.61687593,
#        0.30402384, 0.81181966, 0.68244564, 0.39220748, 0.19757439,
#        0.51472786, 0.13134311, 0.34310624, 0.44707808, 0.46452045,
#        0.83864345, 0.37977268, 0.13008673, 0.05120891, 0.61148699,
#        0.64328881, 0.65706301, 0.80944149, 0.52731265, 0.48847082,
#        0.90936912, 0.58626883, 0.09863693, 0.28000227, 0.90984266,
#        0.38823681, 0.93583245, 0.07944183, 0.26230508, 0.79259228,
#        0.77573097, 0.76314818, 0.50453668, 0.79819276, 0.43120267,
#        0.44005587, 0.90596091, 0.97090606, 0.8769021 , 0.44863964])

# %%
plt.plot(np.random.randn(50))
plt.xlim(-0.5,50)
plt.ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %%
plt.plot(np.random.randn(50))
plt.axis([-1, 50, -3, 3])
# Out:
# (-1.0, 50.0, -3.0, 3.0)

# %%
plt.plot(np.random.randn(50))
plt.axis('tight');

# %% [markdown]
# ## Label

# %%
plt.plot(np.random.randn(50))
plt.title('title')
plt.xlabel('x')
plt.ylabel('yy')
# Out:
# Text(0, 0.5, 'yy')

# %% [markdown]
# ## legend 범례

# %%
plt.plot(np.random.randn(50), ':r', label='A')
plt.plot(np.random.randn(50), 'g--',label='B' )
plt.plot(np.random.randn(50), label='C', linestyle='-.')
plt.plot(np.random.randn(50), label='D')

plt.title('title')
plt.xlabel('x')
plt.ylabel('y')
plt.legend();

# %%
x = np.linspace(0,20, 100)
l = np.cos(x)-np.cos(x[:, np.newaxis])

plt.imshow(l)
plt.colorbar();

# %%
# 그래프 여러개 그리기
for i in range(1, 10):
  plt.subplot(3,3,i) # subplot(총몇행, 총몇열, 그중에 몇번째 그래프인지)
  plt.text(0.5,0.5, str((3,3,i)))

# %%
x = np.arange(1,40)
y = x*1.1
plt.scatter(x, y, marker='.')
plt.axis('equal')
plt.annotate('interesting point', xy=(4, 5), xytext=(20, 10) ,arrowprops=dict(shrink=0.05));

# %%
x1 = np.random.normal(30, 3, 100)
x2 = np.random.normal(20, 3, 100)
x3 = np.random.normal(10, 3, 100)

plt.plot(x1, label='p1')
plt.plot(x2, label='p2')
plt.plot(x3, label='p3')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0, ncol=3, mode='extend', borderaxespad=0.)
plt.annotate("important value", (50, 20), xytext=(5,40), arrowprops=dict(arrowstyle='->'))
plt.annotate("important value", (40, 30), xytext=(50,40), arrowprops=dict(arrowstyle='->'))
# Out:
# Text(50, 40, 'important value')

# %% [markdown]
# # BoxPlot
#
# ## 박스플롯(Box Plot)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
r = np.random.randn(50)
plt.boxplot(r)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1999852c10>,
#   <matplotlib.lines.Line2D at 0x7f1999852eb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1999863190>,
#   <matplotlib.lines.Line2D at 0x7f1999863430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1999852970>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f19998636d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1999863970>],
#  'means': []}

# %% [markdown]
# # 막대플롯

# %%
plt.bar([1,2],[np.random.randn(),np.random.randn()])
# Out:
# <BarContainer object of 2 artists>

# %%
height = [np.random.rand()*i for i in range(1, 6)]
names = ['A', 'B', 'C', 'D', 'E']
y_pos = np.arange(len(names))
plt.bar(y_pos, height)
plt.xticks(y_pos, names, fontweight='bold')
plt.xlabel('group')
# Out:
# Text(0.5, 0, 'group')

# %%
height = [np.random.rand()*i for i in range(1, 6)]
names = ['A', 'B', 'C', 'D', 'E']
y_pos = np.arange(len(names))
plt.barh(y_pos, height)
plt.xticks(y_pos, names, fontweight='bold')
plt.xlabel('group')
# Out:
# Text(0.5, 0, 'group')

# %% [markdown]
# # Stem Plot

# %%
# x = np.linspace(0.1, 2*np.pi, 41)
# y = np.exp(np.sin(x))
x = np.linspace(0.1, 2*np.pi, 41)
y = np.sin(x)
plt.stem(x, y,linefmt='gray', bottom=0)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# # Scatter Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, 'o')

# %%
plt.scatter(x, y, marker='o')

# %%
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x, y)

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 1000*np.random.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='magma')
plt.colorbar()

# %% [markdown]
# # histogram

# %%
data = np.random.randn(10000)
plt.hist(data);

# %%
data = np.random.rand(10000)
plt.hist(data);

# %%
data = np.random.randn(10000)
plt.hist(data, bins=50);

# %%
ret = plt.hist(data, bins=50);
ret
# Out:
# (array([  1.,   1.,   2.,   1.,   1.,   2.,   4.,  12.,  14.,  23.,  22.,
#          35.,  66.,  81., 112., 127., 193., 217., 263., 309., 386., 392.,
#         459., 481., 574., 561., 567., 585., 592., 582., 529., 474., 435.,
#         371., 312., 264., 230., 186., 154., 105.,  91.,  53.,  45.,  32.,
#          19.,  12.,  12.,   6.,   2.,   3.]),
#  array([-4.07053446, -3.92072153, -3.77090859, -3.62109565, -3.47128271,
#         -3.32146977, -3.17165683, -3.0218439 , -2.87203096, -2.72221802,
#         -2.57240508, -2.42259214, -2.2727792 , -2.12296626, -1.97315333,
#         -1.82334039, -1.67352745, -1.52371451, -1.37390157, -1.22408863,
#         -1.0742757 , -0.92446276, -0.77464982, -0.62483688, -0.47502394,
#         -0.325211  , -0.17539806, -0.02558513,  0.12422781,  0.27404075,
#          0.42385369,  0.57366663,  0.72347957,  0.8732925 ,  1.02310544,
#          1.17291838,  1.32273132,  1.47254426,  1.6223572 ,  1.77217014,
#          1.92198307,  2.07179601,  2.22160895,  2.37142189,  2.52123483,
#          2.67104777,  2.8208607 ,  2.97067364,  3.12048658,  3.27029952,
#          3.42011246]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# # 기타

# %%
# 등고선
a = np.arange(-1, 1, 0.1)
X, Y = np.meshgrid(a, a)
Z = np.sin(X*Y)
CS = plt.contour(X, Y, Z, levels=a)
plt.clabel(CS, inline=2)
plt.colorbar();

# %%
def f(x, y):
  return (1 - (x**2+y**2))*np.exp(-y**2/2)
x = np.arange(-1.5, 1.5, 0.1)
y = np.arange(-1.5, 1.5, 0.1)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
N = np.arange(-1, 2, 0.2)

CS = plt.contour(Z, N, linewidths=2, cmap='rainbow')
plt.clabel(CS, inline=True, fmt='%1.1f')
plt.colorbar(CS);

# %%
l = np.linspace(-1.0, 1.0, 1000)
X, Y = np.meshgrid(l, l)
Z = np.sqrt(X**2 + Y**2)
lv = np.linspace(Z.reshape(-1, 1).min(), Z.reshape(-1,1).max(), 40)
plt.contour(X, Y, Z, levels=lv)
plt.colorbar();

# %%
plt.contourf(X, Y, Z, levels=lv)
plt.colorbar();

# %%
plt.imshow(Z, extent=[-1, 1, -1, 1], origin='lower', cmap='rainbow', alpha=0.4);

# %%
Y, X = np.mgrid[0:5:100j,0:5:100j]
U = X
V = np.sin(Y)
plt.streamplot(X, Y, U, V);

# %%
Y, X = np.mgrid[-3:3:100j,-3:3:100j]
U = -1  - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2+V**2)
plt.figure(figsize=(12, 7))
plt.streamplot(X, Y, U, V, density=1);

# %%
import sympy

x, y = sympy.symbols('x y')
f = x**2 + y**2 + x*y - sympy.sin(x)*4
fdx = sympy.diff(f, x)
fdy = sympy.diff(f, y)

sample_size = 100
xs, ys = np.meshgrid(np.linspace(-10, 10, sample_size), np.linspace(-10, 10, sample_size))

zs = [float(f.subs(x, xv).subs(y, yv)) for xv, yv in zip(xs.ravel(), ys.ravel())]
zs = np.array(zs).reshape(sample_size, sample_size)

plt.contour(xs, ys, zs, 40, levels=np.logspace(-0.5, 2.0, 40), cmap='rainbow')

xs_q, ys_q, = np.meshgrid(np.linspace(-10, 10, 10), np.linspace(-10, 10, 10))

xsg = [-float(fdx.subs(x, xv).subs(y, yv)) for xv, yv in zip(xs_q.ravel(), ys_q.ravel())]
ysg = [-float(fdy.subs(x, xv).subs(y, yv)) for xv, yv in zip(xs_q.ravel(), ys_q.ravel())]

plt.quiver(xs_q, ys_q, xsg, ysg, width=0.005, scale=500, color='black');

# %%
data = [10,50,30,40,60]
categories = ['C1', 'C2', 'C3', 'C4', 'C5']
plt.pie(data, labels=categories, autopct='%0.1f%%')
plt.legend(categories);

# %%
explode = [0.0,0.0,0.0,0.1,0.1]
plt.pie(data,explode=explode, labels=categories, autopct='%0.1f%%')
plt.legend(categories);

# %%
import pandas as pd
df = pd.DataFrame({
    'group':['A', 'B', 'C', 'D'],
    'var1':[38,1.5,30,4],
    'var2':[29,10,9,34],
    'var3':[8,39,23,24],
    'var4':[7,31,33,14],
    'var5':[28,15,32,14],
})

categories = list(df)[1:]
N = len(categories)

angles = [n / float(N)*2*np.pi for n in range(N)]
angles += angles[:1]

ax = plt.subplot(111, polar=True)
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_rlabel_position(0)
plt.xticks(angles[:-1], categories)
plt.yticks([10, 20, 30], ['10','20','30'], color='gray', size=7)
plt.ylim(0, 40)

values = df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label='A')
ax.fill(angles, values, 'b', alpha=0.1)

values = df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label='B')
ax.fill(angles, values, 'r', alpha=0.1)

plt.legend(bbox_to_anchor=(0.1,0.1));

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
x = range(1, 101)
y = np.random.randn(100)*x
z = np.random.randn(100)*x

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='green', s=60);

# %%
ax = fig.add_subplot(111, projection='3d')

zline = np.linspace(0, 20, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

zdata = 20 * np.random.random(100)
xdata = np.sin(zdata)+0.2*np.random.randn(100)
ydata = np.cos(zdata)+0.2*np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Blues')
fig

# %%
def f(x, y):
  return np.cos(np.sqrt(x**2+y**2))
l = np.linspace(-4, 4, 20)
X, Y = np.meshgrid(l,l)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='BuPu')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
